# %% [markdown]
# This project is classification of tweet emotion. There was 5 labels.
# 1. Anger
# 2. Happy
# 3. Sadness
# 4. Fear
# 5. Love

# %% [markdown]
# I used all rows of this dataset (4400)

# %% [markdown]
# Algorithm that I used is Automatic MLP using library mlpclassifier. And I get 64% accuracy

# %% [markdown]
# Step by step of this project :
# 1. Import data
# 2. Stemming and Stopwords using library Sastrawi
# 3. Count Vectorized
# 4. Define Target Label
# 5. Split Data for Train dan Test
# 6. Classification Process
# 7. Classification Report
# 8. Try to predict a sentence

# %%
import pandas as pd

# %%
data = pd.read_csv("Twitter_Emotion_Dataset.csv")
data.head()
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
len(data)
# Out:
# 4401

# %%
#Import Library Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory


#Create array for stemming and stopwords process
stem_arr = []
stop_arr = []

for i in range(len(data)):
    
    #stemming
    factory1 = StemmerFactory()
    stemmer = factory1.create_stemmer()
    katadasar = stemmer.stem(str(data['tweet'][i]))
    stem_arr.append(katadasar)
    
    #stopwords
    factory2 = StopWordRemoverFactory()
    stopword = factory2.create_stop_word_remover()
    stop = stopword.remove(katadasar)
    stop_arr.append(stop)

# %%
#show result of stemming
print ("\t\t\t\t\t==== HASIL STEMMING ====\n")
print (stem_arr)
# Out:
# 					==== HASIL STEMMING ====
#
# ['soal jln jatibaru polisi tdk bs gertak gubernur emangny polisi tdk ikut pmbhasan jgn politik atur wilayah hak gubernur soal tn abang soal turun turun pelik perlu sabar username username url', 'sama cewe lho kayak harus bisa lebih rasain lah yang harus sibuk jaga diri rasain sakit haid dan panik pulang malem sendiri gimana orang asing wajar banyak korban yang takut curhat bukan bela malah hujat', 'kepingin gudeg mbarek bu hj amad foto dari google sengaja biar teman jg bayang bagi itu indah', 'jln jatibaru bagi dari wilayah tn abang atur wilayah tgg jwb dan wwnang gub tng abng soal rumit sejak gub2 trdahulu skrg sedng benah agr bermnfaat semua pihak mohon yg punya otak pikir dgn wajar kecuali otak butek ya kamu url', 'sharing alam aja kemarin jam 18 00 batalin tiket di stasiun pasar senen lancar antri tidak terlalu rame 15 menit dan beress semua mungkin bisa coba twips di jam segitu cc username', 'dari sekian banyak thread yang aku baca thread ini paling aneh sih dalam tulis sumpah aneh bgt mau ngatain lebay aja segala bikin thread hadeh aku juga ga jago nulis tapi tulis aku ga beranta thread mbak', 'sharing sama temen tuh emg guna bgt saat lu ngerasa masalah lu berat bgt nyata temen kita sendiri punya masalah lebih berat dr kita malah masalah kita ngga ada apa2nya banding masalah dia', 'orang lain kalau pake ponco itu buat jas hujan nah dia pake buat kasur ya tadi gara2 saking gak punya apa2 mamak bilang kami tuh di awal pernik gak ada ngalamin bulan madu kayak skrg2 org tidur nya aja pake ponco gimane mau bulan madu', 'contoh mereka yg gemar sudut teriak paling toleran tp gemar tuduh gemar men-judge orang dasar versi mereka cukup tau saja', 'pulang udah h-4 lebaran dilema sekali seperti tidak bisa laku apa2 rumah belum lebaran buka puasa bareng cuman 3 hari sama keluarga begitu juga sahur', 'betul min rakyat indonesia sekarang harap nya tinggal sama tni saja kalau yang lain lihat saja sudah jelas serang ke kantor media kata tidak ada unsur pidana sudah jelas hina presiden indonesia yang sah cuma lucu lucu an saja tni url', 'kalaupun fansite ngejual hasil jepret mereka toh uang nya lari ke idol juga beliin mereka hadiah dsb kan kpopers baru ya fansite udh ada dr jaman kamera bom bening skrg', 'sangat syukur bisa doa kakek bung karno sama anak yatim piatu bulanbungkarno junibulanbungkarno penyambunglidahrakyatindonesia nomor2untukjatim jatimpilihgusipulputi kabehsedulurkabehmakmur username h', 'sulit terima nyata memang bahwa ada bagi yang anggap ketika kita interaksi dengan satu orng dari satu golong tentu kita langsung kata golong tentu saat tanpa kita ajar cara utuh dan klaim diri kita paling benar', 'samanye udeh maling semua gak si jancok gak si anjing gak si siluman monyet hahahahaha satu hati sama sama maling', 'ku juga ken ngamuk bacain komen2 netizen yg mahabenar ya lord ga abis pikir komen2 macem gin yg bikin kasus leceh seksual akan tenggelam begitu saja tidak ada hukum untuk laku lebih sedih rerata yg komen jahat adalah perempuan mbaq2 sehat loh url', 'tiap sempat yg pernah hadir tuk dapat buat selalu rasa aman dan nyaman kini jadi suatu hormat yg pernah dapat', 'sedap kali kau ya bobok kasur ku aku tidur kau ikut tidur mau jadi apa kau baca pake logat mamak dahlia di keluarga badak', 'h-9 mau ke bank rame bgt ampe antri tempat duduk ada luar toko emas luber ampe ga liat mbak2nya yg jual ke swalayan antri kasir naudzubilah panjang bener pada bahagia semua kayak moga oh moga rs sepi pasien pada sembuh dan pulang utk bahagia', 'benar2 hancur negara ini kelola amatir tp kenpak username tidak indah statementnya sendiri negara miskin koordinasi jangan asal gagah2an seta salah anulir mana marwahmu wahai mr username presiden url', 'budaya cari dan baca belum nanya ya udah jelas berkali2 kok lama ga atur gaada tentu khusus pakai aja', 'paruh hati ini iri jika lihat orang anak yg masih bisa duduk atau jalan sama ibunda dan paruh hati ini turut empat lihat orang anak yg begitu gundah saat ibunda sakit yang sabar ya kawan mog ...

# %%
#show result of stopwords process
print ("\t\t\t\t\t==== HASIL STOPWORDS ====\n")
print (stop_arr)
# Out:
# 					==== HASIL STOPWORDS ====
#
# ['soal jln jatibaru polisi tdk bs gertak gubernur emangny polisi tdk ikut pmbhasan jgn politik atur wilayah hak gubernur soal tn abang soal turun turun pelik perlu sabar username username url', 'sama cewe lho kayak bisa lebih rasain lah harus sibuk jaga diri rasain sakit haid panik pulang malem sendiri gimana orang asing wajar banyak korban takut curhat bukan bela malah hujat', 'kepingin gudeg mbarek bu hj amad foto google sengaja biar teman jg bayang itu indah', 'jln jatibaru dari wilayah tn abang atur wilayah tgg jwb wwnang gub tng abng soal rumit sejak gub2 trdahulu skrg sedng benah agr bermnfaat semua pihak mohon yg punya otak pikir dgn wajar otak butek kamu url', 'sharing alam aja kemarin jam 18 00 batalin tiket stasiun pasar senen lancar antri terlalu rame 15 menit beress semua mungkin coba twips jam segitu cc username', 'sekian banyak thread aku baca thread paling aneh sih tulis sumpah aneh bgt mau ngatain lebay aja segala bikin thread hadeh aku ga jago nulis tulis aku ga beranta thread mbak', 'sharing sama temen tuh emg bgt lu ngerasa masalah lu berat bgt nyata temen sendiri punya masalah lebih berat dr malah masalah ngga apa2nya banding masalah', 'orang kalau pake ponco buat jas hujan nah pake buat kasur tadi gara2 saking gak punya apa2 mamak bilang tuh awal pernik gak ngalamin bulan madu kayak skrg2 org tidur nya aja pake ponco gimane mau bulan madu', 'contoh yg gemar sudut teriak paling toleran tp gemar tuduh gemar men-judge orang dasar versi cukup tau', 'pulang udah h-4 lebaran dilema sekali tidak laku apa2 rumah lebaran buka puasa bareng cuman 3 hari sama keluarga juga sahur', 'betul min rakyat indonesia sekarang harap nya tinggal sama tni kalau lain lihat jelas serang kantor media kata ada unsur pidana sudah jelas hina presiden indonesia sah cuma lucu lucu an tni url', 'kalaupun fansite ngejual hasil jepret toh uang nya lari idol beliin hadiah kan kpopers baru fansite udh dr jaman kamera bom bening skrg', 'sangat syukur doa kakek bung karno sama anak yatim piatu bulanbungkarno junibulanbungkarno penyambunglidahrakyatindonesia nomor2untukjatim jatimpilihgusipulputi kabehsedulurkabehmakmur username h', 'sulit terima nyata memang ada yang anggap interaksi satu orng satu golong kita langsung kata golong saat kita ajar cara utuh klaim diri kita paling benar', 'samanye udeh maling semua gak si jancok gak si anjing gak si siluman monyet hahahahaha satu hati sama sama maling', 'ku ken ngamuk bacain komen2 netizen yg mahabenar lord ga abis pikir komen2 macem gin yg bikin kasus leceh seksual tenggelam saja ada hukum laku lebih sedih rerata yg komen jahat perempuan mbaq2 sehat loh url', 'tiap sempat yg pernah hadir tuk buat selalu rasa aman nyaman kini jadi suatu hormat yg pernah', 'sedap kali kau bobok kasur ku aku tidur kau ikut tidur mau jadi apa kau baca pake logat mamak dahlia keluarga badak', 'h-9 mau bank rame bgt ampe antri tempat duduk luar toko emas luber ampe ga liat mbak2nya yg jual swalayan antri kasir naudzubilah panjang bener bahagia semua kayak moga moga rs sepi pasien sembuh pulang utk bahagia', 'benar2 hancur negara kelola amatir tp kenpak username indah statementnya sendiri negara miskin koordinasi jangan asal gagah2an seta salah anulir mana marwahmu wahai mr username presiden url', 'budaya cari baca nanya udah jelas berkali2 kok lama ga atur gaada khusus pakai aja', 'paruh hati iri lihat orang anak yg bisa duduk jalan sama ibunda paruh hati turut empat lihat orang anak yg gundah ibunda sakit sabar kawan moga allah beri yg baik kita semua', 'aku senyum bukan arti hidup sempurna aku syukur apa aku punya apa yg tuhan ikan ku', 'mau tdr tidur sampe bgn tdr kok yaa kayak ngerasa aneh ga enak hati udah bawa istighfar aja bgn tdr kayak sedih kayak mikir ga puguh knp bgt coba', 'kan peluk engkau erat2 hingga tak orang yang rebut mu peluk ku happy anniversary syg 6nov 31months', 'kalo mau ganti presiden harus jelas siapa calon terus adu program kerja koalisi ditentuin cuman buat kaos tagar', 'sukses n keren bange ...

# %%
#look the data and count of each label
sentiment_counts = data.label.value_counts()
print("Jumlah data :", len(data),"\n")
print(sentiment_counts)
# Out:
# Jumlah data : 4401
#
# anger      1101
# happy      1017
# sadness     997
# fear        649
# love        637
# Name: label, dtype: int64

# %%
#vectorized 

import numpy as np
from scipy.sparse import hstack
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(ngram_range=(1,2)) # di parsing jadi 1 kalimat
vectorized_data = count_vectorizer.fit_transform(stop_arr) #transformasi jadi vektor
indexed_data = hstack((np.array(range(0,vectorized_data.shape[0]))[:,None], vectorized_data))

def sentiment2target(sentiment):
    return {
        'anger': 0, 'happy': 1, 'sadness': 2, 'fear': 3, 'love': 4
    }[sentiment]

target = data.label.apply(sentiment2target)
print(target)
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
# 5       0
# 6       1
# 7       2
# 8       0
# 9       2
# 10      0
# 11      0
# 12      1
# 13      2
# 14      0
# 15      0
# 16      4
# 17      0
# 18      1
# 19      0
# 20      0
# 21      2
# 22      1
# 23      2
# 24      4
# 25      0
# 26      1
# 27      0
# 28      0
# 29      3
#        ..
# 4371    3
# 4372    1
# 4373    3
# 4374    4
# 4375    0
# 4376    2
# 4377    1
# 4378    0
# 4379    1
# 4380    3
# 4381    2
# 4382    2
# 4383    4
# 4384    1
# 4385    4
# 4386    4
# 4387    3
# 4388    4
# 4389    0
# 4390    4
# 4391    3
# 4392    0
# 4393    2
# 4394    2
# 4395    2
# 4396    4
# 4397    3
# 4398    0
# 4399    1
# 4400    2
# Name: label, Length: 4401, dtype: int64

# %%
#split data (75% for train, 25% for test)

from sklearn.model_selection import train_test_split

data_train, data_test, targets_train, targets_test = train_test_split(indexed_data, target, test_size=0.25, random_state=0)

data_train_index = data_train[:,0] 
data_train = data_train[:,1:]
data_test_index = data_test[:,0]
data_test = data_test[:,1:]

# %%
print("JUMLAH DATA TRAIN :",len(targets_train))
print("JUMLAH DATA TEST :",len(targets_test))
# Out:
# JUMLAH DATA TRAIN : 3300
# JUMLAH DATA TEST : 1101

# %% [markdown]
# # CLASSIFICATION USING MLP

# %%
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier

models = {
    "mlp": MLPClassifier(),
}

# %%
#create model

model = models["mlp"]
model.fit(data_train, targets_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
#evaluation predictions

predictions = model.predict(data_test)
print ("Evaluating..")
print(classification_report(targets_test, predictions))
# Out:
# Evaluating..
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.70       292
#            1       0.62      0.64      0.63       243
#            2       0.51      0.50      0.51       261
#            3       0.74      0.62      0.68       148
#            4       0.76      0.76      0.76       157
#
#     accuracy                           0.64      1101
#    macro avg       0.66      0.65      0.65      1101
# weighted avg       0.64      0.64      0.64      1101

# %% [markdown]
# # PREDICTION OF SENTENCES CLASSIFICATION

# %%
#this sentence is example only

sentences = count_vectorizer.transform(["wah parah, kecewa banget sama kepemimpinan Pak Anies"])
result = model.predict(sentences)

if result==0:
    print("Anger")
elif result==1:
    print("Happy")
elif result==2:
    print("Sadness")
elif result==3:
    print("Fear")
elif result==4:
    print("Love")
else:
    print("Tidak Terdeteksi")
# Out:
# Anger
